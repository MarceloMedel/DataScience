# %%
#Librerias
import pandas as pd
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
from datetime import time
import locale
locale.setlocale(locale.LC_ALL, '')  # Use '' for auto, or force e.g. to 'en_US.UTF-8'

# %matplotlib inline

# %% [markdown]
# ### Data
# * **df_cross_prod**: contiene el par item a - item b y el número de boleta en donde aparece el par
# * **product**: contiene el detalle del item

# %%
#df_cross_prod.to_csv('df_cross_prod.gzip',compression='gz',sep=';')
df_cross_prod = pd.read_csv('data/df_cross_prod.gzip',header=0,sep=';',compression='gzip')
df_cross_prod.head()
df_cross_prod.reset_index(inplace=True)
df_cross_prod.drop(['Unnamed: 0','index'],inplace=True, axis=1)
#df_cross_prod.head()

# %%
df_cross_prod[df_cross_prod['sales_return_document_num']==406235515].head()
# Out:
#    sales_return_document_num  item_a  item_b
# 1                  406235515  231497  231493
# 2                  406235515  231493  231490
# 3                  406235515  231490  231489
# 4                  406235515  300766  231490
# 5                  406235515  356783  231493

# %%
product = pd.read_csv('data/product.csv',sep=';',header=0,index_col=False)
#product.head()

# %%
product.head()
# Out:
#    item_id product_id   sku_id  fl_precio_cmr  precio_normal   brand  \
# 0   100052    1000527  1000527            NaN         3690.0    Idaf
# 1   100053    1000535  1000535            NaN        11890.0    Idaf
# 2   100064    1000640  1000640            NaN        16990.0  Bauker
# 3   100065    1000659  1000659            NaN        34890.0  Bauker
# 4    10009     100099   100099            NaN         4990.0       C
#
#    available_stock            web_category_name sales_quantity  \
# 0              0.0                  Sujetadores            C/U
# 1              0.0  Bisagras Retén para muebles         PAR
# 2             45.0       Accesorios para soldar         C/U
# 3            678.0       Accesorios para soldar         C/U
# 4           1976.0                     Plafones            C/U
#
#                                     desc_words
# 0     ['Trabador', 'de', 'ventana', '6', 'cm']
# 1      ['Escuadra', 'plegable', '25x25', 'cm']
# 2    ['Sujetador', 'magnético', '85x85', 'mm']
# 3  ['Sujetador', 'magnético', '110x110', 'mm']
# 4          ['Plafón', '28,3', 'cm', '60', 'W']

# %%
ab_item_fact = df_cross_prod.groupby(['item_a','item_b']).agg({'sales_return_document_num': pd.Series.nunique})
ab_item_fact.reset_index(inplace=True)
ab_item_fact.info(memory_usage=True,null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9013533 entries, 0 to 9013532
# Data columns (total 3 columns):
# item_a                       9013533 non-null int64
# item_b                       9013533 non-null int64
# sales_return_document_num    9013533 non-null int64
# dtypes: int64(3)
# memory usage: 206.3 MB

# %%
#nodes = ab_item_fact['item_a'].unique()

# %%
#edges = ab_item_fact[['item_a','item_b']].values.tolist()

# %%
#print('Cantidad de nodos: '+str(len(nodes)))
#print('Cantidad de edges: '+str(len(edges)))

# %%
ab_item_fact = pd.merge(ab_item_fact,product[['item_id','web_category_name']],left_on = ['item_a'], right_on=['item_id'],how='left')
#ab_item_fact = pd.merge(ab_item_fact,product[['item_id','web_category_name']],on=['item_id_'],how='left')
#ab_item_fact.head()

# %%
ab_item_fact = pd.merge(ab_item_fact,product[['item_id','web_category_name']],left_on = ['item_b'], right_on=['item_id'],how='left')
#ab_item_fact.head()

# %%
ab_item_fact.drop(['item_id_x','item_id_y'],inplace=True,axis=1)
#rename_col = {'web_category_name_x':'cat_a','web_category_name_y','cat_b'}
ab_item_fact.rename(columns={'web_category_name_x':'cat_a','web_category_name_y':'cat_b'},inplace=True)
#ab_item_fact.head()

# %%
ab_item_fact['item_a'].count()
# Out:
# 9013533

# %%
ab_item_fact.drop(ab_item_fact[ab_item_fact['cat_a'].isnull()].index, inplace=True)
ab_item_fact.drop(ab_item_fact[ab_item_fact['cat_b'].isnull()].index, inplace=True)

# %%
ab_item_fact['item_a'].count()
# Out:
# 6954605

# %%
ab_cat_fact = ab_item_fact.groupby(['cat_a','cat_b']).agg({'sales_return_document_num':'sum'})
#ab_cat_fact.head()

# %%
ab_cat_fact.reset_index(inplace=True)
#ab_cat_fact.head()

# %%
nodes
# Out:
# array([' Fijaciones Adhesivas', ' Textil de Navidad',
#        'Ablandadores de Agua', ..., 'Árboles', 'Árboles Navideños',
#        'Óleos'], dtype=object)

# %%
ab_item_fact.sort_values(by='sales_return_document_num',inplace=True,ascending=False)

# %%
ab_item_fact.head()
# Out:
#          item_a  item_b  sales_return_document_num  \
# 166836    27067   27021                       3673
# 203518    27739   27678                       3636
# 216794    27862   27678                       3356
# 6137449  341962  141208                       2581
# 216810    27862   27739                       2560
#
#                                    cat_a                            cat_b
# 166836       Tubos y Fittings sanitarios      Tubos y Fittings sanitarios
# 203518   Tubos y Fittings PVC hidráulico  Tubos y Fittings PVC hidráulico
# 216794   Tubos y Fittings PVC hidráulico  Tubos y Fittings PVC hidráulico
# 6137449             Escobillones y Palas             Escobillones y Palas
# 216810   Tubos y Fittings PVC hidráulico  Tubos y Fittings PVC hidráulico

# %%
cat_par_group = ab_item_fact.groupby(['cat_a','cat_b']).agg({'sales_return_document_num':'sum'}).reset_index()

# %%
ab_item_fact.head(10)
# Out:
#          item_a  item_b  sales_return_document_num  \
# 166836    27067   27021                       3673
# 203518    27739   27678                       3636
# 216794    27862   27678                       3356
# 6137449  341962  141208                       2581
# 216810    27862   27739                       2560
# 658995    54065   27678                       2526
# 210361    27821   27678                       2522
# 166844    27067   27054                       2401
# 4198132  290635  290630                       2239
# 573797    49546   43067                       2234
#
#                                    cat_a                                cat_b
# 166836       Tubos y Fittings sanitarios          Tubos y Fittings sanitarios
# 203518   Tubos y Fittings PVC hidráulico      Tubos y Fittings PVC hidráulico
# 216794   Tubos y Fittings PVC hidráulico      Tubos y Fittings PVC hidráulico
# 6137449             Escobillones y Palas                 Escobillones y Palas
# 216810   Tubos y Fittings PVC hidráulico      Tubos y Fittings PVC hidráulico
# 658995   Tubos y Fittings PVC hidráulico      Tubos y Fittings PVC hidráulico
# 210361   Tubos y Fittings PVC hidráulico      Tubos y Fittings PVC hidráulico
# 166844       Tubos y Fittings sanitarios          Tubos y Fittings sanitarios
# 4198132     Cables y Alambres Eléctricos         Cables y Alambres Eléctricos
# 573797                Brochas y Pinceles  Diluyentes, Solventes y Limpiadores

# %%
cat_par_group[cat_par_group['cat_a']==cat_par_group['cat_b']]['cat_a'].count()
# Out:
# 960

# %%
np.arange(0, 1000, 50)
# Out:
# array([  0,  50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600,
#        650, 700, 750, 800, 850, 900, 950])

# %%
cat_par_group = cat_par_group[cat_par_group['cat_a']!=cat_par_group['cat_b']]

# %%
cat_par_group.sort_values(by='sales_return_document_num',inplace=True,ascending=False)

# %%
cat_par_group.head()
# Out:
#                                   cat_a                            cat_b  \
# 399264  Tubos y Fittings PVC hidráulico      Tubos y Fittings sanitarios
# 169870        Fitting de cobre y bronce      Tubos y Fittings sanitarios
# 21323                Adhesivos para PVC      Tubos y Fittings sanitarios
# 21321                Adhesivos para PVC  Tubos y Fittings PVC hidráulico
# 74507      Cables y Alambres Eléctricos   Conduits, fitting y accesorios
#
#         sales_return_document_num
# 399264                      57685
# 169870                      51158
# 21323                       50234
# 21321                       47394
# 74507                       32139

# %%
cat_par_group[(cat_par_group['cat_a']=='Tubos y Fittings sanitarios') &
              (cat_par_group['cat_b']=='Tubos y Fittings PVC hidráulico')]
# Out:
#                               cat_a                            cat_b  \
# 400095  Tubos y Fittings sanitarios  Tubos y Fittings PVC hidráulico
#
#         sales_return_document_num
# 400095                      31508

# %%
cat_par_group['cat_x'] = np.where(cat_par_group['cat_a']> cat_par_group['cat_b'], cat_par_group['cat_a'], cat_par_group['cat_b'])

# %%
cat_par_group['cat_y'] = np.where(cat_par_group['cat_a']< cat_par_group['cat_b'], cat_par_group['cat_a'], cat_par_group['cat_b'])

# %%
cat_par_group.head()
# Out:
#                                   cat_a                            cat_b  \
# 399264  Tubos y Fittings PVC hidráulico      Tubos y Fittings sanitarios
# 169870        Fitting de cobre y bronce      Tubos y Fittings sanitarios
# 21323                Adhesivos para PVC      Tubos y Fittings sanitarios
# 21321                Adhesivos para PVC  Tubos y Fittings PVC hidráulico
# 74507      Cables y Alambres Eléctricos   Conduits, fitting y accesorios
#
#         sales_return_document_num                            cat_x  \
# 399264                      57685      Tubos y Fittings sanitarios
# 169870                      51158      Tubos y Fittings sanitarios
# 21323                       50234      Tubos y Fittings sanitarios
# 21321                       47394  Tubos y Fittings PVC hidráulico
# 74507                       32139   Conduits, fitting y accesorios
#
#                                   cat_y
# 399264  Tubos y Fittings PVC hidráulico
# 169870        Fitting de cobre y bronce
# 21323                Adhesivos para PVC
# 21321                Adhesivos para PVC
# 74507      Cables y Alambres Eléctricos

# %%
cat_par_group2 = cat_par_group.groupby(['cat_x','cat_y']).agg({'sales_return_document_num':'sum'}).reset_index()
cat_par_group2.sort_values(by='sales_return_document_num',inplace=True,ascending=False)

# %%
rng = np.random.RandomState(seed=12345)
samples = stats.norm.rvs(size=1000, random_state=rng)
res = stats.cumfreq(samples, numbins=25)

# %%
cat_par_group2
# Out:
#                                   cat_x                            cat_y  \
# 256118      Tubos y Fittings sanitarios  Tubos y Fittings PVC hidráulico
# 255615      Tubos y Fittings sanitarios        Fitting de cobre y bronce
# 255294      Tubos y Fittings sanitarios               Adhesivos para PVC
# 151222              Plantas de Exterior        Consumo Eficiente de Agua
# 253692  Tubos y Fittings PVC hidráulico               Adhesivos para PVC
# 190895                         Rodillos               Brochas y Pinceles
# 45555         Fitting de cobre y bronce                Cañerías de cobre
# 22600    Conduits, fitting y accesorios     Cables y Alambres Eléctricos
# 81337                 Llaves Agua y Gas        Fitting de cobre y bronce
# 75770                             Lijas               Brochas y Pinceles
#
#         sales_return_document_num
# 256118                      89193
# 255615                      65753
# 255294                      51623
# 151222                      49249
# 253692                      49119
# 190895                      37473
# 45555                       35710
# 22600                       34958
# 81337                       34772
# 75770                       34406

# %%
sns.distplot(cat_par_group2[(cat_par_group2['sales_return_document_num'].between(10,100))]['sales_return_document_num'])

# %%
cat_par_group2.groupby(pd.cut(cat_par_group2['sales_return_document_num'], np.arange(0, 100, 10))).count()
# Out:
#                             cat_x   cat_y  sales_return_document_num
# sales_return_document_num
# (0, 10]                    177915  177915                     177915
# (10, 20]                    30679   30679                      30679
# (20, 30]                    14894   14894                      14894
# (30, 40]                     9100    9100                       9100
# (40, 50]                     6059    6059                       6059
# (50, 60]                     4543    4543                       4543
# (60, 70]                     3445    3445                       3445
# (70, 80]                     2692    2692                       2692
# (80, 90]                     2300    2300                       2300

# %%
cat_par_group2[cat_par_group2['sales_return_document_num']<=10]['cat_x'].count()
# Out:
# 177915

# %%
cat_par_group2[(cat_par_group2['sales_return_document_num'].between(10,100))]['cat_x'].count()
# Out:
# 80815

# %%
cat_par_group2[(cat_par_group2['sales_return_document_num'].between(100,1000))]['cat_x'].count()
# Out:
# 18665

# %%
cat_par_group2.head(5)
# Out:
#                                   cat_x                            cat_y  \
# 256118      Tubos y Fittings sanitarios  Tubos y Fittings PVC hidráulico
# 255615      Tubos y Fittings sanitarios        Fitting de cobre y bronce
# 255294      Tubos y Fittings sanitarios               Adhesivos para PVC
# 151222              Plantas de Exterior        Consumo Eficiente de Agua
# 253692  Tubos y Fittings PVC hidráulico               Adhesivos para PVC
#
#         sales_return_document_num
# 256118                      89193
# 255615                      65753
# 255294                      51623
# 151222                      49249
# 253692                      49119

# %%
#cat_par_group2.groupby('cat_x').agg({'sales_return_document_num':'sum'}).sort_values(by='sales_return_document_num',ascending=False)

# %%
#cat_par_group2[cat_par_group2['sales_return_document_num']<=10].sort_values(by='sales_return_document_num',ascending=False)

# %%
nodes = cat_par_group2['cat_x'].unique()

# %%
edges = cat_par_group2[cat_par_group2['sales_return_document_num'].between(100,1000)]#.values.tolist()
edges = edges[['cat_x','cat_y','sales_return_document_num']]
#edges.drop_duplicates(subset=['cat_a','cat_b'],keep='first',inplace=True)
#edges = edges.values.tolist()

# %%
edges.head()
# Out:
#                                            cat_x  \
# 31237   Delantales, Toma Ollas y Paños de Cocina
# 23598               Consumo Eficiente de Energía
# 7039                            Bolsas de Basura
# 227736                     Tarugos para concreto
# 255346               Tubos y Fittings sanitarios
#
#                                  cat_y  sales_return_document_num
# 31237        Consumo Eficiente de Agua                       1000
# 23598   Alfombras Just Home Collection                        999
# 7039          Accesorios de lavandería                        999
# 227736              Clavos para techos                        998
# 255346                      Aspersores                        998

# %%
print('Cantidad de nodos: '+str(len(nodes)))
print('Cantidad de edges: '+str(len(edges)))
# Out:
# Cantidad de nodos: 1129
# Cantidad de edges: 18665

# %% [markdown]
# #### Disaster!

# %%
import networkx as nx
import community
from cytoolz import keymap, keyfilter, valmap, valfilter, itemmap, frequencies
import random

prod_graph = nx.Graph()
prod_graph.add_nodes_from(nodes)
print('Nodes added')
prod_graph.add_edges_from(edges[['cat_x','cat_y']].values.tolist())
#prod_graph.add_weighted_edges_from(edges[['cat_x','cat_y','sales_return_document_num']].values.tolist(),weight='sales_return_document_num')
print('Edges added')

import time
start_time = time.time()
dendrogram = community.generate_dendrogram(prod_graph, random_state=1312)
print("Dendrogram created in {:.2f} seconds ---".format(time.time() - start_time))


#for level in range(len(dendrogram) - 1) :
#    print(level)
#    print("Partition at level", level,"is", partition_at_level(dendo, level))

import time
start_time = time.time()    
communities = community.partition_at_level(dendrogram, len(dendrogram) - 1)
print("Communities created in {:.2f} seconds ---".format(time.time() - start_time))
community_sizes = frequencies(communities.values())
print('# of Communities:', len(community_sizes))
# Out:
# Nodes added
# Edges added
# Dendrogram created in 0.83 seconds ---
# Communities created in 0.00 seconds ---
# # of Communities: 406

# %%
network = prod_graph

# %%
print("graph has {:d} nodes with {:d} edges".format(nx.number_of_nodes(network),nx.number_of_edges(network)))
print(nx.number_connected_components(network),"connected components")
# Out:
# graph has 1130 nodes with 18665 edges
# 402 connected components

# %%
nx.draw_random(network)

# %%
nx.draw_circular(network)

# %%
nx.draw_spectral(network)

# %%
nx.draw_spring(network)

# %%
#for level in range(len(dendrogram) - 1) :
#    print(level)
#    print("Partition at level", level,"is", partition_at_level(dendrogram, level))

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
# use graphviz to find radial layout
pos=nx.graphviz_layout(G,prog="twopi",root=0)
# draw nodes, coloring by rtt ping time
nx.draw(G,pos,
        node_color=[G.rtt[v] for v in G],
        with_labels=False,
        alpha=0.5,
        node_size=15)
# adjust the plot limits
xmax=1.02*max(xx for xx,yy in pos.values())
ymax=1.02*max(yy for xx,yy in pos.values())
plt.xlim(0,xmax)
plt.ylim(0,ymax)
#plt.savefig("lanl_routes.png")

# %%
from matplotlib.colors import rgb2hex

palette = sns.color_palette('colorblind', n_colors=len(community_sizes))
# esto convierte cada color a una representación hexadecimal, como la usada en los Sitios Web
palette = list(map(rgb2hex, palette))
print(palette)
# este método grafica la paleta de colores
sns.palplot(palette)
plt.axis('off');
# Out:
# ['#0173b2', '#de8f05', '#029e73', '#d55e00', '#cc78bc', '#ca9161', '#fbafe4', '#949494', '#ece133', '#56b4e9', '#0173b2', '#de8f05', '#029e73', '#d55e00', '#cc78bc', '#ca9161', '#fbafe4', '#949494', '#ece133', '#56b4e9', '#0173b2', '#de8f05', '#029e73', '#d55e00', '#cc78bc', '#ca9161', '#fbafe4', '#949494', '#ece133', '#56b4e9', '#0173b2', '#de8f05', '#029e73', '#d55e00', '#cc78bc', '#ca9161', '#fbafe4', '#949494', '#ece133', '#56b4e9', '#0173b2', '#de8f05', '#029e73', '#d55e00', '#cc78bc', '#ca9161', '#fbafe4', '#949494', '#ece133', '#56b4e9', '#0173b2', '#de8f05', '#029e73', '#d55e00', '#cc78bc', '#ca9161', '#fbafe4', '#949494', '#ece133', '#56b4e9', '#0173b2', '#de8f05', '#029e73', '#d55e00', '#cc78bc', '#ca9161', '#fbafe4', '#949494', '#ece133', '#56b4e9', '#0173b2', '#de8f05', '#029e73', '#d55e00', '#cc78bc', '#ca9161', '#fbafe4', '#949494', '#ece133', '#56b4e9', '#0173b2', '#de8f05', '#029e73', '#d55e00', '#cc78bc', '#ca9161', '#fbafe4', '#949494', '#ece133', '#56b4e9', '#0173b2', '#de8f05', '#029e73', '#d55e00', '#cc78bc', '#ca9161', '#fbafe4', '#949494', '#ece133', '#56b4e9', '#0173b2', '#de8f05', '#029e73', '#d55e00', '#cc78bc', '#ca9161', '#fbafe4', '#949494', '#ece133', '#56b4e9', '#0173b2', '#de8f05', '#029e73', '#d55e00', '#cc78bc', '#ca9161', '#fbafe4', '#949494', '#ece133', '#56b4e9', '#0173b2', '#de8f05', '#029e73', '#d55e00', '#cc78bc', '#ca9161', '#fbafe4', '#949494', '#ece133', '#56b4e9', '#0173b2', '#de8f05', '#029e73', '#d55e00', '#cc78bc', '#ca9161', '#fbafe4', '#949494', '#ece133', '#56b4e9', '#0173b2', '#de8f05', '#029e73', '#d55e00', '#cc78bc', '#ca9161', '#fbafe4', '#949494', '#ece133', '#56b4e9']

# %%
community_structure = nx.DiGraph()

node_from_h = {}

dst_to_node = None

for level, comms in enumerate(dendrogram, start=0):
    if dst_to_node is None:
        src_to_node = {}
    else:
        src_to_node = dst_to_node
        
    dst_to_node = {}
    
    for src, dst in comms.items():
        if not src in src_to_node:
            src_node_id = community_structure.number_of_nodes()
            community_structure.add_node(src_node_id)
            src_to_node[src] = src_node_id
            
            node_from_h[src_node_id] = src
            
        if not dst in dst_to_node:
            dst_node_id = community_structure.number_of_nodes()
            community_structure.add_node(dst_node_id)
            dst_to_node[dst] = dst_node_id
            
        community_structure.add_edge(dst_to_node[dst], src_to_node[src])
        
root_node_id = community_structure.number_of_nodes()
community_structure.add_node(root_node_id)

for src, dst in dendrogram[-1].items():
    community_structure.add_edge(root_node_id, dst_to_node[dst])
    
community_structure.number_of_nodes(), community_structure.number_of_edges()
# Out:
# (1445, 1444)

# %%
# source: https://stackoverflow.com/questions/34803197/fast-b-spline-algorithm-with-numpy-scipy
import scipy.interpolate as si
import numpy as np

def scipy_bspline(cv, n=100, degree=3, periodic=False):
    """ Calculate n samples on a bspline

        cv :      Array ov control vertices
        n  :      Number of samples to return
        degree:   Curve degree
        periodic: True - Curve is closed
    """
    cv = np.asarray(cv)
    count = cv.shape[0]

    # Closed curve
    if periodic:
        kv = np.arange(-degree,count+degree+1)
        factor, fraction = divmod(count+degree+1, count)
        cv = np.roll(np.concatenate((cv,) * factor + (cv[:fraction],)),-1,axis=0)
        degree = np.clip(degree,1,degree)

    # Opened curve
    else:
        degree = np.clip(degree,1,count-1)
        kv = np.clip(np.arange(count+degree+1)-degree,0,count-degree)

    # Return samples
    max_param = count - (degree * (1-periodic))
    spl = si.BSpline(kv, cv, degree)
    return spl(np.linspace(0,max_param,n))

# %%
node_to_h = itemmap(reversed, node_from_h)
community_structure_undirected = community_structure.to_undirected()

def edge_to_spline(src, dst, n_points=100, smoothing_factor=1):
    edge_path = nx.shortest_path(community_structure_undirected, node_to_h[src], node_to_h[dst])
    edge_cp = [hierarchical_pos[node_id] for node_id in edge_path]
    
    try:    
        smooth_edge = scipy_bspline(edge_cp, degree=min(len(edge_cp) - 1, 3), n=n_points)
        source_edge = np.vstack((np.linspace(edge_cp[0][0], edge_cp[-1][0], num=n_points, endpoint=True),
                                 np.linspace(edge_cp[0][1], edge_cp[-1][1], num=n_points, endpoint=True))).T
        
        if smoothing_factor < 1.0:
            smooth_edge = smooth_edge * smoothing_factor + source_edge * (1.0 - smoothing_factor)
        
        return smooth_edge
    except ValueError:
        print(src, dst, 'error')
        return None

# %%
print('¿Es árbol la estructura de comunidades?', nx.is_tree(community_structure))
print('¿Es árbol la red de músicos?', nx.is_tree(network))
# Out:
# ¿Es árbol la estructura de comunidades? True
# ¿Es árbol la red de músicos? False

# %%
hierarchical_pos = nx.drawing.nx_pydot.graphviz_layout(community_structure, prog='twopi', root=root_node_id)

# %%
circular_positions = keyfilter(lambda x: x in node_from_h, hierarchical_pos)
circular_positions = keymap(lambda x: node_from_h[x], circular_positions)
print(len(circular_positions), network.number_of_nodes())
# Out:
# 1140 1140

# %%
# source: https://stackoverflow.com/questions/34803197/fast-b-spline-algorithm-with-numpy-scipy
import scipy.interpolate as si
import numpy as np

def scipy_bspline(cv, n=100, degree=3, periodic=False):
    """ Calculate n samples on a bspline

        cv :      Array ov control vertices
        n  :      Number of samples to return
        degree:   Curve degree
        periodic: True - Curve is closed
    """
    cv = np.asarray(cv)
    count = cv.shape[0]

    # Closed curve
    if periodic:
        kv = np.arange(-degree,count+degree+1)
        factor, fraction = divmod(count+degree+1, count)
        cv = np.roll(np.concatenate((cv,) * factor + (cv[:fraction],)),-1,axis=0)
        degree = np.clip(degree,1,degree)

    # Opened curve
    else:
        degree = np.clip(degree,1,count-1)
        kv = np.clip(np.arange(count+degree+1)-degree,0,count-degree)

    # Return samples
    max_param = count - (degree * (1-periodic))
    spl = si.BSpline(kv, cv, degree)
    return spl(np.linspace(0,max_param,n))

# %%
node_to_h = itemmap(reversed, node_from_h)
community_structure_undirected = community_structure.to_undirected()

def edge_to_spline(src, dst, n_points=100, smoothing_factor=1):
    edge_path = nx.shortest_path(community_structure_undirected, node_to_h[src], node_to_h[dst])
    edge_cp = [hierarchical_pos[node_id] for node_id in edge_path]
    
    try:    
        smooth_edge = scipy_bspline(edge_cp, degree=min(len(edge_cp) - 1, 3), n=n_points)
        source_edge = np.vstack((np.linspace(edge_cp[0][0], edge_cp[-1][0], num=n_points, endpoint=True),
                                 np.linspace(edge_cp[0][1], edge_cp[-1][1], num=n_points, endpoint=True))).T
        
        if smoothing_factor < 1.0:
            smooth_edge = smooth_edge * smoothing_factor + source_edge * (1.0 - smoothing_factor)
        
        return smooth_edge
    except ValueError:
        print(src, dst, 'error')
        return None

# %%
edge_lines = []
smoothing_factor = 0.7
 #resolución de cada arista en vértices. más puntos, mejor calidad de imagen, pero más tiempo de cálculo y de dibujo.
n_points = 50

for src, dst in network.edges():    
    edge_lines.append(edge_to_spline(src, dst, n_points=n_points, smoothing_factor=smoothing_factor))

# %%
# elegimos 5 nodos al azar
sample_keys = random.sample(communities.keys(), 10)
# mostramos el subdiccionario que tiene esos 5 nodos
keyfilter(lambda x: x in sample_keys, communities)
# Out:
# {'Bajada de Cama': 0,
#  'Baño': 2,
#  'Destornilladores': 1,
#  'Listel de cocina': 86,
#  'Maceteros': 0,
#  'Mamparas para duchas ': 2,
#  'Muebles Complemento para baños': 0,
#  'Máscaras de soldar': 2,
#  'Quitasoles de playa': 126,
#  'Sujetadores': 1}

# %%
node_colors = valmap(lambda x: palette[x], communities)
keyfilter(lambda x: x in sample_keys, node_colors)
# Out:
# {'Bajada de Cama': '#0173b2',
#  'Baño': '#029e73',
#  'Destornilladores': '#de8f05',
#  'Listel de cocina': '#fbafe4',
#  'Maceteros': '#0173b2',
#  'Mamparas para duchas ': '#029e73',
#  'Muebles Complemento para baños': '#0173b2',
#  'Máscaras de soldar': '#029e73',
#  'Quitasoles de playa': '#fbafe4',
#  'Sujetadores': '#de8f05'}

# %%
edge_colors = []

for src, dst in network.edges():
    if communities[src] == communities[dst]:
        edge_colors.append(node_colors[src])
    else:
        edge_colors.append('lightgray')

# %%
network

# %%
from matplotlib.collections import LineCollection

fig, ax = plt.subplots(1, 1, figsize=(12, 12))

# dibujamos los nodos en sus posiciones
nx.draw_networkx_nodes(network, ax=ax, pos=circular_positions, 
                 node_color=[node_colors[n] for n in network.nodes],
                 node_size=20,
                 with_labels=False)

# dibujamos las aristas que hemos calculado
#edge_collection = LineCollection(edge_lines, color=edge_colors, linewidth=1, linestyle='solid', alpha=0.1)
#ax.add_collection(edge_collection)

ax.set_axis_off()

# %%
positions = nx.drawing.nx_pydot.graphviz_layout(network, prog='neato')
#pos=nx.graphviz_layout(network,prog="twopi",root=0)

#nx.draw(G,pos,
#        node_color=[G.rtt[v] for v in G],
#        with_labels=False,
#        alpha=0.5,
#        node_size=15)
# adjust the plot limits
#xmax=1.02*max(xx for xx,yy in pos.values())
#ymax=1.02*max(yy for xx,yy in pos.values())
#plt.xlim(0,xmax)
#plt.ylim(0,ymax)
#fig, ax = plt.subplots(1, 1, figsize=(12, 12))
#nx.draw_networkx(network, ax=ax, pos=positions)
#ax.set_axis_off()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-220-73a071212dba> in <module>
# ----> 1 positions = nx.drawing.nx_pydot.graphviz_layout(network, prog='neato')
#       2 #pos=nx.graphviz_layout(network,prog="twopi",root=0)
#       3
#       4 #nx.draw(G,pos,
#       5 #        node_color=[G.rtt[v] for v in G],
#
# ~\Anaconda3\lib\site-packages\networkx\drawing\nx_pydot.py in graphviz_layout(G, prog, root)
#     266     This is a wrapper for pydot_layout.
#     267     """
# --> 268     return pydot_layout(G=G, prog=prog, root=root)
#     269
#     270
#
# ~\Anaconda3\lib\site-packages\networkx\drawing\nx_pydot.py in pydot_layout(G, prog, root)
#     341
#     342         if isinstance(node, list):
# --> 343             node = node[0]
#     344         pos = node.get_pos()[1:-1]  # strip leading and trailing double quotes
#     345         if pos is not None:
#
# IndexError: list index out of range

# %%
positions

# %%
# nota: el código es el mismo de antes, solamente cambiamos la posición de los nodos
pos = nx.layout.circular_layout(network)

fig, ax = plt.subplots(1, 1, figsize=(12,12))

nx.draw_networkx_edges(network, pos=pos, edge_color='#abacab', node_size=0, alpha=0.25)
#nx.draw_networkx_edges(network, pos=positions, edge_color='#abacab', node_size=0, alpha=0.25)

for community_id, color in enumerate(palette, start=0):
    community_nodes = valfilter(lambda x: x == community_id, communities).keys()
    community_graph = nx.subgraph(network, community_nodes)

    nx.draw_networkx_edges(community_graph, pos=pos, edge_color=color, node_size=0, alpha=0.1)
    nx.draw_networkx_nodes(community_graph, pos=pos, node_color=color, node_size=20, with_labels=False)

plt.axis('off');
